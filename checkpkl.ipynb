# %%
import pickle

# %%
with open('./util/checkpt.pkl', 'rb') as file:
    data = pickle.load(file)

# %%
data = data.data

# %%
data.keys()
# Out:
# dict_keys([2])

# %%
from  pprint import pprint
pprint(data[2][1].shape)
# Out:
# (3, 72, 128)

# %%
image = data[2][1].reshape(72, 128, 3)
type(image)
# Out:
# numpy.ndarray

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20, 20))
imgplot = plt.imshow(image)
